# %%
# Imports
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import sys
# %matplotlib inline

# %%
# My function imports
sys.path.insert(0, '../models/')
import data_functions as data_functions
import plot_functions as plot_functions
import train_functions as train_functions

# %%
# Other bits
sns.set_style('whitegrid')
flatui = ["#9b59b6", "#3498db", "#95a5a6", "#e74c3c", "#34495e", "#2ecc71"]
sns.set_palette(flatui)

# %%
# Data
d_train = pd.read_csv('../data/processed/d_train')
d_test = pd.read_csv('../data/processed/d_test')
d_validate = pd.read_csv('../data/processed/d_validate')
d_train = d_train.set_index(['conversation', 'segment'])
d_test = d_test.set_index(['conversation', 'segment'])
d_validate = d_validate.set_index(['conversation', 'segment'])

# First segment is someone introducing the clip so remove
d_train = d_train.query('segment != 1')
dataframes = {'train': d_train, 'test': d_test, 'validate': d_validate}

# %%
# # Radu data
# radu_dataframes = {'train': [], 'test': [], 'validate': []}

# for name, dataframe in dataframes.items():
    
#     radu_dataframes[name] = dataframe.copy()
#     radu_dataframes[name]['g/d'] = None
#     radu_dataframes[name]['segment_ratio'] = None
#     radu_dataframes[name]['gap_change'] = None
#     conversations = dataframe.index.get_level_values(0).unique()

#     for conversation in conversations:
#         # Get conversation and shifted conversation dataframes
#         conversation_df = dataframe.loc[conversation]
#         conversation_df_shift = conversation_df.shift(1)

#         # Create useful features
#         gap_duration = conversation_df_shift['gap'] / conversation_df['duration']
#         segment_ratio = conversation_df_shift['duration'] / conversation_df['duration']
#         gap_change = conversation_df_shift['gap'] - conversation_df['gap']

#         # Update
#         radu_dataframes[name].loc[conversation, 'g/d'].update(gap_duration)
#         radu_dataframes[name].loc[conversation, 'segment_ratio'].update(segment_ratio)
#         radu_dataframes[name].loc[conversation, 'gap_change'].update(gap_change)

#     radu_dataframes[name].dropna(inplace=True)
#     radu_dataframes[name] = radu_dataframes[name][['n_words', 'duration', 'gap', 'type']]

# %%
#radu_dataframes['validate'].head()

# %% [markdown]
# ## Data editing to use Radus features

# %% [markdown]
# # Basic prediction model

# %% [markdown]
# ## Machine learning

# %% [markdown]
# We first make the features amenable to machine learning. To do this we take the mean of the three features which are:
# - Number of words per segment of speech
# - Duration of that segment of speech
# - Gap between that person talking

# %%
def generate_mean_dfs(dataframes):

    mean_dfs = {}

    for key in dataframes.keys():
        mean_dfs[key] = pd.DataFrame(columns=[*dataframes[list(dataframes.keys())[0]].columns])

    for name, df in dataframes.items():

        conversations = df.reset_index()['conversation'].unique()
        # std deviation code
#         mean_dfs['std_n_words'] = None
#         mean_dfs['std_duration'] = None
#         mean_dfs['std_gap'] = None
        
        for conversation in conversations:
            update = df.loc[conversation][[i for i in df.columns if i != 'type']].apply(np.mean)
            update['type'] = df.loc[conversation].iloc[0]['type']
            # Code to include standard deviation
#             update['std_n_words'] = df.loc[conversation]['n_words'].describe()['std']
#             update['std_gap'] = df.loc[conversation]['gap'].describe()['std']
#             update['std_duration'] = df.loc[conversation]['duration'].describe()['std']
            mean_dfs[name] = mean_dfs[name].append(update, ignore_index=True)

        mean_dfs[name].loc[mean_dfs[name]['type'] == 'good', ['type']] = 1
        mean_dfs[name].loc[mean_dfs[name]['type'] == 'bad', ['type']] = 0
        mean_dfs[name].reset_index(inplace=True)
        mean_dfs[name].drop(['index'], axis=1, inplace=True)

    return mean_dfs

# %%
mean_df = generate_mean_dfs(dataframes)
validate_df = mean_df.pop('validate')
mean_df['train']
# Out:
#        n_words   duration       gap  type  std_duration   std_gap  std_n_words
# 0    82.882353  32.355294  0.590588     1     51.655291  0.852690   117.157417
# 1   156.545455  61.560909  0.644545     1     63.154201  0.482024   155.581724
# 2    23.027027   8.008514  0.811622     1     11.758947  1.161262    36.292560
# 3   141.875000  45.465625  0.514375     1     43.493714  0.471536   130.732233
# 4    51.844444  16.333556  0.369111     1     34.342207  0.371042   109.083778
# 5    61.457143  18.905143  0.777429     1     40.013056  1.067610   124.330996
# 6    41.000000  13.089455  0.513636     1     24.155893  0.679897    69.155488
# 7    34.086207  11.905690  0.384310     1     29.926895  0.398247    92.047525
# 8   239.818182  73.833636  0.458182     1     67.204273  0.375867   221.471361
# 9   142.166667  52.209167  0.773333     1     59.906404  0.625813   157.482370
# 10   18.973214   5.738214  0.313750     1      8.402410  0.471177    25.810278
# 11   32.847458  11.087119  0.497119     1     17.990827  0.758092    51.489140
# 12   37.692308  12.293269  0.529038     1     26.268807  0.826311    60.128796
# 13   54.840909  17.150227  0.631364     1     34.567506  0.764465   118.747914
# 14   81.857143  26.410000  0.660000     1     73.054643  0.815044   223.613044
# 15   61.324324  19.386757  0.482432     1     27.217859  0.395976    84.134170
# 16  255.625000  82.043750  0.493750     1     72.581550  0.298134   212.376981
# 17  136.333333  45.944667  0.384000     1     32.396896  0.291690    94.771655
# 18  207.750000  66.903750  0.462500     1     68.620196  0.467967   206.157187
# 19   48.531915  14.709787  0.438723     1     21.518861  0.441739    67.100460
# 20   59.314286  20.464571  0.782571     1     35.668573  0.685314   104.180209
# 21   59.314286  20.464571  0.782571     1     35.668573  0.685314   104.180209
# 22   75.033333  24.598000  0.659333     1     48.381350  0.750668   132.494238
# 23  154.714286  52.927143  0.774286     1     74.083727  0.779000   202.605501
# 24   81.200000  25.401200  0.565600     1     36.663852  0.533081   117.608106
# 25  150.785714  49.225714  0.670714     1     74.245199  0.324807   227.605657
# 26   54.472222  18.603611  0.548333     1     25.336202  0.548262    72.998820
# 27   72.758621  23.273103  0.698966     1     28.861707  0.514027    94.382828
# 28   58.972973  18.876757  0.569730     1     18.959504  0.710987    60.516979
# 29   53.244444  16.238667  0.357778     1     33.517249  0.348411   108.248904
# 30   71.343750  22.590000  0.504062     1     60.131418  0.446426   185.537164
# 31   29.160494   8.472099  0.437037     1     17.160524  0.520962    54.149205
# 32   76.482759  25.301379  0.635172     1     28.134015  0.690495    80.218728
# 33   30.014286   9.754286  0.543429     1     19.101266  0.464040    53.681695
# 34   49.325000  17.586500  0.861500     1     24.805989  0.915397    67.266171
# 35  157.142857  54.690000  0.588571     1     52.653608  0.550983   144.877060
# 36   34.672414  12.274138  0.409138     1     21.283016  0.445454    54.138026
# 37  106.000000  35.881905  0.928095     1     37.287207  0.924422   102.737530
# 38   37.500000  11.904559  0.572059     1     20.638282  0.677334    66.047134
# 39   52.347826  17.415217  0.465870     1     31.388987  0.435173    88.626361
# 40   38.276923  12.722154  0.520462     1     23.282477  0.452595    69.939820
# 41   90.000000  25.715000  0.610000     0     25.731616  0.763675    93.338095
# 42   13.351351   3.824865  0.365135     0      4.594051  0.316970    13.159737
# 43   14.541985   3.665649  0.198092     0      5.417237  0.197512    18.998486
# 44   51.159091  13.907727  0.208636     0     11.482605  0.216232    41.614478
# 45   30.826923   7.986154  0.188269     0      7.883479  0.190836    29.062962
# 46   50.931034  12.709828  0.234310     0     10.663488  0.165361    41.172236
# 47   49.888889  13.705185  0.229259     0     12.344340  0.225694    43.675669
# 48   55.880597  15.503881  0.296716     0     15.195127  0.285155    50.055279
# 49   47.775862  15.097759  0.316552     0     14.117657  0.346388    38.798645

# %%
X, y, X_train, y_train, X_test, y_test = data_functions.generate_test_training(mean_df)
X_full = X

# %%
X_validate = validate_df.drop(['type'], axis=1)
y_validate = list(map(int, validate_df['type'].values))

# %% [markdown]
# #### Feature correlation matrix

# %%
corr = X_full.corr()

f, ax = plt.subplots(figsize=(11, 9))

cmap = sns.diverging_palette(220, 10, as_cmap=True)

mask = np.zeros_like(corr, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True

sns.heatmap(corr, cmap=cmap, mask=mask, vmax=.3, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5});

# %% [markdown]
# #### Normalise features

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X, X_test, X_validate = scaler.transform(X), scaler.transform(X_test), scaler.transform(X_validate)

# %% [markdown]
# Get the full sets, training and test sets for this new form of the data. Then train the classifiers.

# %%
classifiers = train_functions.train_classifiers(X_train, y_train, X_test, y_test)
# Out:
# Training accuracies
# ----------
# Logistic Regression Training accuracy: 94.12%
# KNN Training accuracy: 96.08%
# SVM Training accuracy: 98.04%
# Decision Tree Training accuracy: 80.02%
# Random Forest Training accuracy: 87.99%
# ADA Boost Training accuracy: 86.15%
# GBC Training accuracy: 86.15%
#
# ------------------------------------------------------------
#
# Test accuracies
# ----------
# Logistic Regression test accuracy: 85.46%
# KNN test accuracy: 85.46%
# SVM test accuracy: 89.63%
# Decision Tree test accuracy: 92.96%
# Random Forest test accuracy: 92.96%
# ADA Boost test accuracy: 92.96%
# GBC test accuracy: 92.96%

# %% [markdown]
# ### Gridsearch

# %%
gs_classifiers = train_functions.perform_gridsearch(classifiers, X_train, y_train)
# Out:
# Logistic Regression best parameters {'C': 0.2, 'penalty': 'l2'}:
# KNN best parameters {'algorithm': 'auto', 'n_neighbors': 3}:
# SVM best parameters {'C': 0.1, 'gamma': 'auto', 'kernel': 'linear'}:
# Decision Tree best parameters {'criterion': 'gini', 'max_depth': 1, 'min_samples_leaf': 3}:
# Random Forest best parameters {'bootstrap': True, 'criterion': 'entropy', 'max_depth': 12, 'max_features': 1, 'min_samples_leaf': 3, 'min_samples_split': 3}:
# ADA Boost best parameters {'learning_rate': 0.02, 'n_estimators': 16}:
# GBC best parameters {'learning_rate': 0.6, 'n_estimators': 100, 'subsample': 0.4}:

# %%
train_functions.calculate_cv(gs_classifiers, X_train, y_train)
# Out:
# Logistic Regression cross validation score: 96.18%
# KNN cross validation score: 96.18%
# SVM cross validation score: 96.18%
# Decision Tree cross validation score: 90.14%
# Random Forest cross validation score: 90.14%
# ADA Boost cross validation score: 90.14%
# GBC cross validation score: 88.14%

# %%
train_functions.calculate_cv(gs_classifiers, X_test, y_test)
# Out:
# Logistic Regression cross validation score: 81.14%
# KNN cross validation score: 89.14%
# SVM cross validation score: 85.14%
# Decision Tree cross validation score: 88.0%
# Random Forest cross validation score: 92.0%
# ADA Boost cross validation score: 92.0%
# GBC cross validation score: 88.0%

# %% [markdown]
# #### Plot learning curve

# %% [markdown]
# Logistic regression appears to be the best. Here we plot the learning curve.

# %%
plot_functions.learning(gs_classifiers, X, y)
#plt.savefig('../reports/learning_curves', dpi=300)

# %% [markdown]
# #### ROC curve

# %%
plot_functions.roc_ollie(gs_classifiers, X, y)

# %% [markdown]
# ## Validation

# %%
print('Validation set accuracy \n' + '*'*30 + '\n')

for name, clf in gs_classifiers.items():
    score = clf.score(X_validate, y_validate)
    print('{}: {:.1f}%'.format(name, score*100))
# Out:
# Validation set accuracy
# ******************************
#
# Logistic Regression: 92.1%
# KNN: 92.1%
# SVM: 89.5%
# Decision Tree: 86.8%
# Random Forest: 92.1%
# ADA Boost: 89.5%
# GBC: 92.1%

# %%
plot_functions.roc_ollie(gs_classifiers, X_validate, y_validate)
plt.savefig('../reports/ROC', dpi=300)

# %% [markdown]
# ### Feature importances

# %%
features = {'Normal': ['Number of words', 'Duration', 'Gap'],
            'Radu': ['Number of words', 'g/d', 'Segment Ratio', 'Gap Change']}

# Check feature sizes 
forest = gs_classifiers['Random Forest']
importances = forest.feature_importances_
std = np.std([tree.feature_importances_ for tree in forest.estimators_],
             axis=0)
indices = np.argsort(importances)[::-1]

# Print the feature ranking
print("Feature ranking:")

for f in range(X.shape[1]):
    print("{}: {:.3f}".format(features['Normal'][f], importances[indices[f]]))
# Out:
# Feature ranking:
# Number of words: 0.303
# Duration: 0.227
# Gap: 0.154
# std_dur: 0.129
# std_gap: 0.103
# std_words: 0.084

# %% [markdown]
# <br>
# <br>
# # Are our values correct?

# %%
cbt_session = pd.read_pickle('../data/processed/real/cbt_session')
child_interview = pd.read_pickle('../data/processed/real/child_interview')
real_mean_dfs = {'CBT Session': cbt_session,
            'Child interview': child_interview}

for name, df in real_mean_dfs.items():
    real_mean_dfs[name] = pd.DataFrame(data=df.describe().loc['mean']).T

# %%
for data_name, df in real_mean_dfs.items():
    
    print('For {} \n'.format(data_name) + '*'*30)

    for clf_name, clf in classifiers.items():
        prediction = ('GOOD' if clf.predict(df) == 1 else 'BAD')
        print('{} predicts: {}.'.format(clf_name, prediction))
        
    print('\n')

# %% [markdown]
# <br>
# <br>
# # Time dependence

# %% [markdown]
# This is todo. The idea here is to use the model derived from above then at each timestep find the probability score for that segment, this give us a p and a 1-p that we can apply Bayes with. We then repeat for the next timestep which will give us a running odds score and an indication as to how the converation is going.

# %%
# For d_train conversation = 1
# Change good bad to binary 
for name, df in dataframes.items():
    df['type'][df['type'] == 'good'] = 1
    df['type'][df['type'] == 'bad'] = 0
    
conversation = d_train.loc[1].drop(['type'], axis=1)

for segment in conversation.reset_index()['segment'].unique():
    segment = conversation.loc[segment]
    pred = gs_classifiers['Random Forest'].predict_proba([segment])
# Out:
# /Users/jambo/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# /Users/jambo/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
